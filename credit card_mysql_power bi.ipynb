# %%
import pandas as pd
from datetime import datetime

# %%
import sqlalchemy as sal
#import mysqlconnector
from sqlalchemy import create_engine

# %%
df=pd.read_csv("C:/Users/safana.y.rasheet.ali/Desktop/MySQL practice/Credit_Card_Financial_Dashboard-main/credit_card.csv")

# %%
df.head(100)
# Out:
#     Client_Num Card_Category  Annual_Fees  Activation_30_Days  \
# 0    708082083          Blue          200                   0
# 1    708083283          Blue          445                   1
# 2    708084558          Blue          140                   0
# 3    708085458          Blue          250                   1
# 4    708086958          Blue          320                   1
# ..         ...           ...          ...                 ...
# 95   708292833          Blue          150                   1
# 96   708295533          Blue          250                   0
# 97   708296883          Blue          280                   0
# 98   708298233          Blue          125                   0
# 99   708300483          Blue          245                   0
#
#     Customer_Acq_Cost Week_Start_Date Week_Num Qtr  current_year  \
# 0                  87      1-Jan-2023   Week-1  Q1          2023
# 1                 108      1-Jan-2023   Week-1  Q1          2023
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10108 entries, 0 to 10107
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Client_Num             10108 non-null  int64
#  1   Card_Category          10108 non-null  object
#  2   Annual_Fees            10108 non-null  int64
#  3   Activation_30_Days     10108 non-null  int64
#  4   Customer_Acq_Cost      10108 non-null  int64
#  5   Week_Start_Date        10108 non-null  object
#  6   Week_Num               10108 non-null  object
#  7   Qtr                    10108 non-null  object
#  8   current_year           10108 non-null  int64
#  9   Credit_Limit           10108 non-null  float64
#  10  Total_Revolving_Bal    10108 non-null  int64
#  11  Total_Trans_Amt        10108 non-null  int64
#  12  Total_Trans_Vol        10108 non-null  int64
#  13  Avg_Utilization_Ratio  10108 non-null  float64
# ...

# %%
def convert_date(date_str):
    try:
        # Try parsing the first format
        date_obj = datetime.strptime(date_str, "%d-%b-%Y")
    except ValueError:
        # If it fails, try the second format
        date_obj = datetime.strptime(date_str, "%d-%m-%Y")
    finally:
        return date_obj

# %%
date_list=list(df['Week_Start_Date'])

# %%
a=datetime.strftime(convert_date('16-03-2023'),'%Y-%m-%d')

# %%
a
d=[]

# %%
df['formatted_date']=[datetime.strftime(convert_date(date),'%Y-%m-%d') for date in df['Week_Start_Date']]
#print(d)

# %%
"""for date in df['Week_Start_Date']:
    df['date']=datetime.strftime(convert_date(date),'%d-%b-%Y')"""
# Out:
# "for date in df['Week_Start_Date']:\n    df['date']=datetime.strftime(convert_date(date),'%d-%b-%Y')"

# %%
#df['formatted_date']
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10108 entries, 0 to 10107
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Client_Num             10108 non-null  int64
#  1   Card_Category          10108 non-null  object
#  2   Annual_Fees            10108 non-null  int64
#  3   Activation_30_Days     10108 non-null  int64
#  4   Customer_Acq_Cost      10108 non-null  int64
#  5   Week_Start_Date        10108 non-null  object
#  6   Week_Num               10108 non-null  object
#  7   Qtr                    10108 non-null  object
#  8   current_year           10108 non-null  int64
#  9   Credit_Limit           10108 non-null  float64
#  10  Total_Revolving_Bal    10108 non-null  int64
#  11  Total_Trans_Amt        10108 non-null  int64
#  12  Total_Trans_Vol        10108 non-null  int64
#  13  Avg_Utilization_Ratio  10108 non-null  float64
# ...

# %%
df.head(100)
# Out:
#     Client_Num Card_Category  Annual_Fees  Activation_30_Days  \
# 0    708082083          Blue          200                   0
# 1    708083283          Blue          445                   1
# 2    708084558          Blue          140                   0
# 3    708085458          Blue          250                   1
# 4    708086958          Blue          320                   1
# ..         ...           ...          ...                 ...
# 95   708292833          Blue          150                   1
# 96   708295533          Blue          250                   0
# 97   708296883          Blue          280                   0
# 98   708298233          Blue          125                   0
# 99   708300483          Blue          245                   0
#
#     Customer_Acq_Cost Week_Start_Date Week_Num Qtr  current_year  \
# 0                  87      1-Jan-2023   Week-1  Q1          2023
# 1                 108      1-Jan-2023   Week-1  Q1          2023
# ...

# %%
#df=df.drop(columns=['date'])

# %%
df.head()
# Out:
#    Client_Num Card_Category  Annual_Fees  Activation_30_Days  \
# 0   708082083          Blue          200                   0
# 1   708083283          Blue          445                   1
# 2   708084558          Blue          140                   0
# 3   708085458          Blue          250                   1
# 4   708086958          Blue          320                   1
#
#    Customer_Acq_Cost Week_Start_Date Week_Num Qtr  current_year  Credit_Limit  \
# 0                 87      1-Jan-2023   Week-1  Q1          2023        3544.0
# 1                108      1-Jan-2023   Week-1  Q1          2023        3421.0
# 2                106      1-Jan-2023   Week-1  Q1          2023        8258.0
# 3                150      1-Jan-2023   Week-1  Q1          2023        1438.3
# 4                106      1-Jan-2023   Week-1  Q1          2023        3128.0
#
#    Total_Revolving_Bal  Total_Trans_Amt  Total_Trans_Vol  \
# 0                 1661            15149              111
# ...

# %%
df['Week_Start_Date']=df['formatted_date']

# %%
#df=df.drop(columns=df.columns[0])
df=df.drop(columns='formatted_date')

# %%
#engine=sal.create_engine('mysql://cdc2-l-433dq1s/nashville?driver=ODBC+Driver+17+FOR+SQL+SERVER')
engine= sal.create_engine("mysql+mysqlconnector://root:#Learning247@localhost/explore")
conn=engine.connect()

# %%
df.to_sql('cc_detail_df',con=conn,index=False,if_exists='append')
# Out:
# 10108

# %%
df.columns

# %%
# it has extra columns as index
df.to_csv('credit_cards.csv',index=False)
